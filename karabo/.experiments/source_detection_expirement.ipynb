# %%
import numpy as np

from karabo.simulation.sky_model import SkyModel
from karabo.sourcedetection import detect_sources_in_image
from karabo.Imaging.imager import Imager
from karabo.simulation.telescope import get_MEERKAT_Telescope
from karabo.simulation.interferometer import InterferometerSimulation
from karabo.simulation.observation import Observation

# %%
flux_range = np.linspace(0.1, 10, 20)

observation = Observation(1e8)
sim = InterferometerSimulation()
telescope = get_MEERKAT_Telescope()

detections = []

for flux in flux_range:
    sky = SkyModel(np.array([[250, 60, flux]]))
    visibility = sim.run_simulation(telescope, sky, observation)
    imager = Imager(
        visibility, imaging_npixel=2048, imaging_cellsize=3.878509448876288e-05
    )
    image = imager.get_dirty_image()
    detection = detect_sources_in_image(image)
    detections.append(detection)
# Out:
# W|
# W|== WARNING: No GPU capability available.
# W|
# <SkyCoord (ICRS): (ra, dec) in deg
#     (0., 0.)>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/karabo_dev_env/lib/python3.8/site-packages/bdsf/readimage.py:377, in Op_readimage.init_beam(self, img)
#     376 try:
# --> 377     beam = (hdr['BMAJ'], hdr['BMIN'], hdr['BPA'])
#     378     found = True
#
# File ~/opt/anaconda3/envs/karabo_dev_env/lib/python3.8/site-packages/astropy/io/fits/header.py:157, in Header.__getitem__(self, key)
#     155     keyword = key
# --> 157 card = self._cards[self._cardindex(key)]
#     159 if card.field_specifier is not None and keyword == card.rawkeyword:
#     160     # This is RVKC; if only the top-level keyword was specified return
#     161     # the raw value, not the parsed out float value
#
# File ~/opt/anaconda3/envs/karabo_dev_env/lib/python3.8/site-packages/astropy/io/fits/header.py:1754, in Header._cardindex(self, key)
#    1753 if not indices:
# -> 1754     raise KeyError(f"Keyword {keyword!r} not found.")
#    1756 try:
#
# KeyError: "Keyword 'BMAJ' not found."
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 9>()
#      12 imager = Imager(visibility, imaging_npixel=2048, imaging_cellsize=3.878509448876288e-05)
#      13 image = imager.get_dirty_image()
# ---> 14 detection = detect_sources_in_image(image)
#      15 detections.append(detection)
#
# File ~/development/SKA/karabo/sourcedetection/source_detection.py:49, in detect_sources_in_image(image, beam)
#      39 """
#      40 Detecting sources in an image. The Source detection is impemented with the PyBDSF.process_image function.
#      41 See https://www.astron.nl/citt/pybdsf/process_image.html for more information.
#    (...)
#      46 :return: Source Detection Result containing the found sources
#      47 """
#      48 import bdsf
# ---> 49 detection = bdsf.process_image(image.file.path, beam=beam, quiet=True, format='csv')
#      50 return PyBDSFSourceDetectionResult(detection)
#
# File ~/opt/anaconda3/envs/karabo_dev_env/lib/python3.8/site-packages/bdsf/__init__.py:253, in process_image(input, **kwargs)
#     249     img.opts.debug = kwargs['debug']
#     251 # Now process it. Any kwargs specified by the user will
#     252 # override those read in from the parameter save file or dictionary.
# --> 253 img.process(**kwargs)
#     254 return img
#
# File ~/opt/anaconda3/envs/karabo_dev_env/lib/python3.8/site-packages/bdsf/image.py:135, in Image.process(self, **kwargs)
#     133 """Process Image object"""
#     134 from . import interface
# --> 135 success = interface.process(self, **kwargs)
#     136 return success
#
# File ~/opt/anaconda3/envs/karabo_dev_env/lib/python3.8/site-packages/bdsf/interface.py:62, in process(img, **kwargs)
#      60 img, op_chain = get_op_chain(img)
#      61 if op_chain is not None:
# ---> 62     _run_op_list(img, op_chain)
#      63     img._prev_opts = img.opts.to_dict()
#      64 return True
#
# File ~/opt/anaconda3/envs/karabo_dev_env/lib/python3.8/site-packages/bdsf/__init__.py:152, in _run_op_list(img, chain)
#     150         answ = raw_input_no_history(prompt)
#     151 op.__start_time = time()
# --> 152 op(img)
#     153 op.__stop_time = time()
#     154 gc.collect()
#
# File ~/opt/anaconda3/envs/karabo_dev_env/lib/python3.8/site-packages/bdsf/readimage.py:122, in Op_readimage.__call__(self, img)
#     120 ### initialize wcs conversion routines
#     121 self.init_wcs(img)
# --> 122 self.init_beam(img)
#     123 self.init_freq(img)
#     124 year, code = self.get_equinox(img)
#
# File ~/opt/anaconda3/envs/karabo_dev_env/lib/python3.8/site-packages/bdsf/readimage.py:381, in Op_readimage.init_beam(self, img)
#     378     found = True
#     379 except:
#     380     ### try see if AIPS as put the beam in HISTORY as usual
# --> 381    for h in hdr['HISTORY']:
#     382       # Check if h is a string or a FITS Card object (long headers are
#     383       # split into Cards as of PyFITS 3.0.4)
#     384       if not isinstance(h, str):
#     385         hstr = h.value
#
# File ~/opt/anaconda3/envs/karabo_dev_env/lib/python3.8/site-packages/astropy/io/fits/header.py:150, in Header.__getitem__(self, key)
#     148         key = key.upper()
#     149         # Special case for commentary cards
# --> 150         return _HeaderCommentaryCards(self, key)
#     152 if isinstance(key, tuple):
#     153     keyword = key[0]
#
# File ~/opt/anaconda3/envs/karabo_dev_env/lib/python3.8/site-packages/astropy/io/fits/header.py:2214, in _HeaderCommentaryCards.__init__(self, header, keyword)
#    2212 super().__init__(header)
#    2213 self._keyword = keyword
# -> 2214 self._count = self._header.count(self._keyword)
#    2215 self._indices = slice(self._count).indices(self._count)
#
# File ~/opt/anaconda3/envs/karabo_dev_env/lib/python3.8/site-packages/astropy/io/fits/header.py:1380, in Header.count(self, keyword)
#    1377 # We have to look before we leap, since otherwise _keyword_indices,
#    1378 # being a defaultdict, will create an entry for the nonexistent keyword
#    1379 if keyword not in self._keyword_indices:
# -> 1380     raise KeyError(f"Keyword {keyword!r} not found.")
#    1382 return len(self._keyword_indices[keyword])
#
# KeyError: "Keyword 'HISTORY' not found."
